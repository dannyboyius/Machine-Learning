# %% [markdown]
# <a href="https://colab.research.google.com/github/dannyboyius/Machine-Learning/blob/master/DFT_GW__Submission_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DATA FEED AND TECHNOLOGY
#
# ## Group Work Submission-3   GROUP 2D
#
#
# - Bruno Jordan Orfei Abe (brunojordan@gmail.com)
# - Daniel Kwaku Boateng (dannyboyius@gmail.com)
# - Alexander Victor Okhuese (alexandervictor16@yahoo.com)
# - Theophilus Addae (adei.blesson@gmail.com)
# - Idris Ayinde (idrisayinde@yahoo.com)

# %% [markdown]
# # INTRODUCTION
#
# Emerging Technologies are making the financial market more secured and safe with the gradual elimination of third parties by the assistance of Blockchain, a distributed ledger technology (DLT) in the exchange of resources on the stock exchange and over the counter services. Technologies such as Bitcoin which was to simply track ownership of Bitcoins (a currency) and Ethereum blockchain which
# focuses on creating a decentralized, general-purpose platform for running code enabling a diverse range of decentralized applications.
# These technogies have hugely impacted the life of transaction on the stock and commodity markrts taking advantage of the blockchain features, as a complete transparency, tamper-resistant, and public transaction ledger that is replicated and held by a distributed set of nodes. As a general-purpose ledger for method of recording certain transactions. Transactions in their simplest form are events where one person sends something to another person, eg: Kwaku sends Adjoa 4 USD. This is a transaction. In this case, the ledger should help in keeping track of the total amount, the sender and the receiver. This is why it is possible for the blockchain software to be run on many computers all around the world, without compromising security because the data in a blockchain is cryptographically secured so that any attempted change to the data it contains is easy to detect
#
# Ten years before the invention of Bitcoin in 2008, In 1994, Nick Szabo, an American cryptographer and computer scientist realized that the decentralized ledger could be used for smart contracts also known as self-executing contracts, blockchain contracts, or digital contracts. In 1998, Nick Szabo who invented a virtual currency called "Bit Gold" also defined smart contracts as computerized transaction protocols that execute terms of a contract. Smart contracts render transactions traceable, transparent, and irreversible.He said, "in this format,contracts could be converted to computer code, stored and replicated on the system and supervised by the network of computers that run the blockchain.
#
# In our first submission the group explored the use of C# and Excel to keep track of the pricing of various properties by Setting up a worksheet, when the application is launched for the first time it creates a new Excel workbook titled “property_pricing.xlsx”. Implemented command line interface, where property information can be added to the sheet. We also updated statistical methods which were already declared to perform the correct work based on the data from the sheet.
#
# In our second submission, we explored different blockchain platforms by comparing key concepts of different blockchain technologies such as Bitcoin,
# Ethereum, Hyperledger and Corda. The group also presented a discussion on features of these emerging technologies that makes it preferable in fintech market: Scalability of the system, the ability of the system to process millions of transactions per second without capacity constraints. The ease of adding new block to the chain by meeting the requierd Proof-of Work so that  integrity of the ledger is maintained, which is consensus protocol. Considering the degree to which users and transactions are private, It’s privacy and the decentralized nature makes it difficult for central point of failure to impact ledger transaction. One of the features that makes these emerging technologies unique is the concept of a payment being irrevocable- once a payment is made, and settled, it cannot be reversed, Settlement finality.
#
# In this third and final submission, we explore smart contracts, it’s current and future relevance to financial engineering. The group would explore key concepts in smart contracts. In the report, we would look at the overview by describing smart contract, explain how it function and achieve this functionality in the Ethereum. we would explain five advantages and disadvantages of using smart contracts as compared to traditional trading solutions. We would also identify and describe one use-case for smart contracts in the report.

# %% [markdown]
# # Overview
#
# Smart contract is an emerging technology made possible by public blockchains.
#
# *Nick Szabo in 1998*, defined smart contracts "as computerized transaction protocols that execute terms of a contract".
#
# Although, bitcoin was the first to support basic smart contracts, bitcoin is limited to the currency use case. While bitcoin aims to disrupt PayPal and online banking, ethereum intend using a blockchain to replace internet third parties by providing a blockchain with a built-in fully fledged Turing-complete programming language that allows users to create “Contracts” used to encode arbitrary state transition functions in the fintech markets.
# Smart contract is a computer protocol intended to digitally facilitate, verify, or enforce the negotiation or performance of a contract. Smart contracts allow the performance of credible transactions without third parties. This results in ledger feedback such as transferring money and receiving the product or service. Smart contracts allow the performance of credible transactions without third parties.
#
# Although it is   difficult to understand compared to a traditional or standard contract, in which the the terms of a relationship are enforceable by law, a smart contract enforces a relationship with cryptographic code. In otherwise, smart contracts are programs that execute exactly as they are set up to by their creators.
# Users of smart contracts claim, because of its ability to partially or fully self-execute, self-enforce, or both and considering the aim of smart contracts to provide security, reduce transaction costs associated with contracting makes it preferable to traditional contract law in current and future fintech markets.
#
# Ethereum Virtual Machine (EVM) code can encode any computation that can be conceivably carried out, including infinite loops. EVM code allows looping in two ways. First, there is a JUMP instruction that allows the program to jump back to a previous spot in the code, and a JUMPI instruction to do conditional jumping, allowing for statements like while x < 27: x = x * 2. Second, contracts can call other contracts, potentially allowing for looping through recursion.
# Ethereum is a platform that is built specifically for creating smart contracts. In contrast, ethereum replaces bitcoin’s more restrictive scripting language of hundred or more and replaces it with a language that allows developers to write their own programs.
# Ethereum allows developers to program their own smart contracts, or ‘autonomous agents’, as they are call in the Ethereum white paper. The language is ‘Turing-complete’, meaning it supports a broader set of computational instructions.
#
#  ## Functions of Smart Contract
#
# Functions are sections of code that execute certain bits of logic. For example, in the CryptoHunt ICO we implemented a requestRefund function which people could call to get their investment back on the ICO's failure.
#
# When a smart contract is  translated into machine language for Ethereum to nunderstand the language, it's hashed, that is, compressed into an unreadable format. IT needs a special bit of code called Application Binary Interface (ABI required to interact with a smart contract. ABI is used to call the unreadable functions from the Ethereum address, such as  contract's address intended to facilitate “communication” between the two standards.
# ABIs are generally generated during compilation and will be placed into a separate file next to the Solidity source code or in a tool which does the compiling (e.g. Remix).
#
# It's important to note that an ABI does not need to match the contract's source code 100%. If a contract has 10 functions of which only one is myFunction, then an ABI with just that one function defined is enough to call that one function, ignoring the rest.
#
#
#
# ## How does Ethereum achieve smart contract capabilities?
#
# Ethereum achieve smart contract through the Blockchain structure component called the Hashing, cryptography.
#
# Blockchain Structure
# Now that we have a high-level understanding of what blockchains are, let’s dive a bit more into how they actually work. Remember: a blockchain is  a complete, permanent, public, and decentralized transaction ledger, which can be  broken down into several components:
# 1. Hashing (cryptography)
# 2. Private / public key cryptography
# 3. Merkle trees
# 4. Consensus (BFT, PoW).
#
# ## Hashing
# An important concept in blockchain is that of a hash. A hash function is simply a
# function that takes data as input and outputs different data in a deterministic manner.
# The hash functions used in blockchains have three particular security properties. Considering the mathematical definition for a hash function H, followed by a more colloquial explanation:
# 1. Collision-free, infeasible to find distinct xx and yy such that H(x)=H(y)H(x)=H(y).
# 2. Hiding, given H(x)H(x), it is infeasible to find the value of xx.
# 3. Puzzle-friendly, for all output yy, kk chosen from a high min-entropy distribution, it is
# infeasible to find xx such that H(k|x) = yH(k|x) = y.
# Collision-free means that it is hard to find two values that hash to the same
# value. Hiding means that, given a hash, it is difficult to find the value that gave you that hash. Finally puzzle-friendly means that it is hard to find a piece of data to append to a given piece of data to give a desired hash. Puzzle-friendliness is important for proof-of-work mining, which is explained a bit more later in the course, so please don’t linger too long on this third property – it is mentioned for completeness of the definition.

# %% [markdown]
# # Advantages and Disadvantages
# Smart contracts are replacing the traditional process with their advantages. As we explain five benefits of the smart contract.
#
# ## Total Transparency
#
# Smart contracts are entirely transparent to all of their concerned members. Anyone from the relevant persons will have access to see all the terms and conditions of the agreements. If anyone wants any changes, they have to decide it before the contracts are ready. Once the contract is prepared, there will be no argument on this.
#
# ## No Miscommunication
#
# Now you know that the smart contracts examples are entirely automatic and they have all the information with every single detail. So, it means that there is no chance for any miscommunication or misunderstanding. Every communication among the network will be 100% clear and automatic. There will be no communication gap.
#
# ## Efficient Performance
#
# The smart contract can assure you about their efficient operation. The combination of accuracy, speed, and the automated feature will complete the whole contract process efficiently without any fault or any interruption of a middleman. They will process a huge number of transaction with higher efficiency.
#
# ## No Paperwork
#
# Smart contracts are contributing to nature by avoiding the paperwork. They are using the virtual world for all of their processing, and thus they are entirely removing the use of paper. It’s a significant contribution to the environment and the world as well. They are making better both the real world and the business world.
#
# ## Backup
#
# There’s a probability that bank can lose your documents or accounts. The smart contract always comes with backup. There will be many duplicates of your papers on the blockchain. So, there will be no chance of losing any of them.
# Smart contracts permanently record all your essential documents with explicit details. Whenever you need any information, you can find them easily in their storage. The most important part is, you can retrieve any of the information if there’s any data loss.
#
# Trustworthy
#
# You can’t trust anyone blindly that they will never lose your documents, can you? But, you can trust a smart contract for never losing your records as they will encrypt them on a shared ledger.
# Smart contracts are entirely trustworthy. They execute all their work automatically using their network. So, there will be no fear of losing, manipulating or having any error with your documentation. There will be an entirely trustworthy execution of every process.
#
# Guaranteed Outcomes
#
# Smart contracts allow its member to create any agreements on their own. But they have to do this following some rules that will make the deals more significant. There will be no interruption of external courts. You just need to follow all the rules they bind you with.

# %% [markdown]
# # Use cases of Smart Contract
# There are several places smart contracts are deplored. The smart contract is possessing the traditional system of records and agreements.
#
# Records Storing
#
# The smart contract comes with the digitalization of the Uniform Commercial Code filling. Thus, they can store records, release and renew them automatically whenever they need. Moreover, if there’s any necessity or requirement of removing any record permanently by the law, they can also do that automatically.
#
# Trading Activities
#
# The traditional trading financial activities always required a middleman making the process time consuming and costly. Smart contract eliminates middlemen while using the Letter of Credit methods. Thus, making the whole trading finance process simpler, efficient and less costly for the buyers and suppliers.
#
# Protecting the Copyright
#
# Smart contracts blockchain can preserve the content of the copyright. When a group works together, there might be some confusions about the responsibilities and the rights to that work. If there will be a complete record of all the responsibilities and the rights along with the respective persons, it will be straightforward for the team members to cooperate with each other.
# Smart contract technology can make the teamwork easy for you. It will keep all the tracks of the collaboration using a decentralized blockchain system. There will be no more doubt about the right and responsibility.
#
# Insurance Claim
#
# You all know it very well that the process for an insurance claim is a very long time process. This is so complicated and irritating for both the customers and the insurance companies. It’s not their fault. The insurance claim requires so many formalities and paperwork to complete. It is a great example of smart contracts applications.
# Smart contracts blockchain can streamline and modify the whole claiming process with automated technology. It will recognize any condition and state the claim automatically itself. Thus, it will manage the rest of the process without any error.
#
# Government Voting Service
#
# Most of the government are based on the voting system. We do not doubt on the topic that the manual voting systems are not 100% accurate. Most of the voting process is lengthy and inappropriate.
# A smart contract comes with the ledger-protected voting system. This system provides highly protected coding and higher computing power. It is almost impossible to decode and hack the entire system. Moreover, it will also require a huge computing power.
# This process will be completely accurate and faster than the manual voting sys
#
# Internet of Things Network
#
# When smart contracts blockchain work along with the IoT, it becomes stronger, more efficient, and significant. Together they move towards the best and advanced application for the industries. IoT, Internet of Things, makes the smart contract definitely a more powerful technology.
# They make a powerful network using both hardware and software and make it possible to be applicable in real life. They make the perfect technology being a perfect combination.

# %% [markdown]
# # Application of one use case
#
# ## Cloud Computing
#
# From the Ethereum white paper;The Ethereum Virtual Machine (EVM) technology is used to create a verifiable computing environment, allowing users to ask others to perform  computations and ask for proofs of computations at randomly selected time if the computations were done correctly.
# This allows for the creation of a cloud computing market where users can participate with their desktop, laptop or specialized server, and spot-checking together with security deposits can be used to ensure that the system is trustworthy.
#
# In theory, it combines the control that people had over their information in the past with the easy-to-access information that we’re used to in the digital age. Each time you save edits, or add or delete notes, every node on the network makes the change.
#
# ![image.png](data:image/png;base64,...)
#
# With Ethereum, every time a program is used, a network of thousands of computers processes it. Contracts written in a smart contract-specific programming languages are compiled into ‘bytecode’, which a feature called the ‘Ethereum Virtual Machine’ (EVM) can read and execute.
# In the network above every node holds a copy of the transaction and smart contract history of the network as well as keeping track of the current ‘state’. Whenever a user performs a transaction eg. Where Jamie request payment of $100 and it is paid, all of the nodes on the network come to a concesus that this change took place. This is for the network of miners and nodes to take responsibility for transferring the shift from state to state, rather than some authority such as PayPal or a bank. Bitcoin miners validate the shift of ownership of bitcoins from one person to another. The EVM executes a contract with whatever rules the developer initially programmed. Actual computation on the EVM is achieved through a stack-based bytecode language, ones and zeroes that a machine can read but developers can write smart contracts in high-level languages such as Solidity and Serpent that are easier for humans to read and write. All the nodes execute this contract using their EVMs.

# %% [markdown]
# # Conclusion
#
# ## The Future of Contracts
# Recently, an amazingly great technology has occurred in the market, and it has replaced the old traditional process of handling the contracts and agreements. This is the new blockchain technology along with its new smart contracts blockchain. Welcome to the world of blockchain technology and its smart contracts.
# At first, it was mainly created to maintain the Bitcoin cryptocurrency. But, soon after, the developers realize how potential the technology can be to replace the traditional record storing system. There’s also a cryptocurrency named Ethereum. They also considered Ethereum as the future for the contracts technology with its exclusive blockchain platform.
# The blockchain is an enormous digital ledger of  transactions. This ledger can keep a record of anything important with the explicit details. Besides, you can use this to keep records of financial accounts, ownership activities, claims, birth and death certificates, medical procedures and other important things which computer code can record.
